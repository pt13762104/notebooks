# %%
# GPU support 
# !sudo apt install lshw clpeak -y

# %%
#!clpeak
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
#https://stackoverflow.com/questions/1196074/start-a-background-process-in-python
import os
os.environ["OLLAMA_KEEP_ALIVE"]="-1"
os.environ["OLLAMA_NUM_PARALLEL"]="1"
os.environ["OLLAMA_FLASH_ATTENTION"]="1"
import subprocess

# %%
def run_in_background(s):
    subprocess.Popen(s.split())

# %%
run_in_background("ollama serve")

# %%
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz

# %%
# !sudo tar -xvzf ngrok-v3-stable-linux-amd64.tgz -C /usr/local/bin

# %%
from kaggle_secrets import UserSecretsClient
import os
user_secrets = UserSecretsClient()
os.environ["token"] = user_secrets.get_secret("ngrok_token")
domain = user_secrets.get_secret("domain")

# %%
# !ngrok config add-authtoken $token

# %%
run_in_background(f"ngrok http --host-header=localhost:11434 --domain={domain} 11434")
