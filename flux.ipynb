# %%
from kaggle_secrets import UserSecretsClient
import os
import subprocess
user_secrets = UserSecretsClient()
os.environ["token"] = user_secrets.get_secret("ngrok_token")
domain = user_secrets.get_secret("domain")

# %%
# !cd ~ && git clone https://github.com/comfyanonymous/ComfyUI.git
# !cd ~/ComfyUI && pip install -r requirements.txt
# !pip install xformers
# !cd ~/ComfyUI/custom_nodes/ && git clone https://github.com/ltdrdata/ComfyUI-Manager
# !cd ~/ComfyUI/models/unet/ && wget https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/flux1-dev-fp8.safetensors
# !cd ~/ComfyUI/models/unet/ && wget https://huggingface.co/Kijai/flux-fp8/resolve/main/flux1-schnell-fp8.safetensors
# !cd ~/ComfyUI/models/clip/ && wget https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp16.safetensors
# !cd ~/ComfyUI/models/clip/ && wget -O clip.safetensors https://huggingface.co/openai/clip-vit-large-patch14/resolve/main/model.safetensors
# !cd ~/ComfyUI/models/vae/ && wget https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/ae.sft
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/anime_lora_comfy_converted.safetensors
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/art_lora_comfy_converted.safetensors
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/disney_lora_comfy_converted.safetensors
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/mjv6_lora_comfy_converted.safetensors
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/realism_lora_comfy_converted.safetensors
# !cd ~/ComfyUI/models/loras/ && wget https://huggingface.co/XLabs-AI/flux-lora-collection/resolve/main/scenery_lora_comfy_converted.safetensors

# %%
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !sudo tar -xvzf ngrok-v3-stable-linux-amd64.tgz -C /usr/local/bin
# !ngrok config add-authtoken $token

# %%
def run_in_background(s):
    subprocess.Popen(s.split())
run_in_background("python /root/ComfyUI/main.py")
run_in_background(f"ngrok http --host-header=localhost:8188 --domain={domain} 8188")
